# %%
from PIL import Image
import requests

class club:
  def __init__(self, name, im, score):
    self.name = name
    self.im = im
    self.score = score


leipzig = club("leipzig", Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/2603790.png", stream=True).raw),78)
city = club("city",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/52919.png", stream=True).raw),93)
brugge = club("brugge",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50043.png", stream=True).raw),72)
benfica = club("benfica",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50147.png", stream=True).raw),82)
liverpool = club("liverpool",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/7889.png", stream=True).raw),86)
real = club("real",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50051.png", stream=True).raw),92)
milan = club("milan",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50058.png", stream=True).raw),80)
spurs = club("spurs",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/1652.png", stream=True).raw),82)
frankfurt = club ("frankfurt",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50072.png", stream=True).raw),74)
napoli = club ("napoli",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50136.png", stream=True).raw),87)
dortmund = club ("dortmund",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/52758.png", stream=True).raw),83)
chelsea = club("chelsea",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/52914.png", stream=True).raw),82)
porto = club("porto",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50064.png", stream=True).raw),80)
inter = club("inter",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50138.png", stream=True).raw),80)
psg = club("psg",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/52747.png", stream=True).raw),89)
bayern = club("bayern",Image.open(requests.get("https://img.uefa.com/imgml/TP/teams/logos/140x140/50037.png", stream=True).raw),91)

t = Image.open("t.png")
t1 = Image.open("t1.png")
t2 = Image.open("t2.png")
t3 = Image.open("t3.png")

# %%
def draw(club, pos):
    ax = fig.add_subplot(size[0],size[1], pos)
    plt.imshow(club.im)
    plt.axis('off')

def drawline():
    linepos = [2,6,10,14,21,29,42]
    for i in linepos:
        ax = fig.add_subplot(size[0],size[1], i)
        plt.imshow(t)
        plt.axis('off')
        ax = fig.add_subplot(size[0],size[1], size[0]*size[1]-i-1)
        plt.imshow(t1)
        plt.axis('off')
    ax = fig.add_subplot(5,5, 14)
    plt.imshow(t3)
    plt.axis('off')
 
def drawchamp(champ):
    ax = fig.add_subplot(5,5,14)
    plt.imshow(champ.im)
    plt.axis('off')


def win(pair):
    return random.choices(pair,[pair[0].score,pair[1].score],k=1)[0]

# %%
import matplotlib.pyplot as plt
fig = plt.figure() 
size = 9, 17 
n=size[0]*size[1]-1
club_pair = [[leipzig,city],[brugge,benfica],[liverpool,real],[milan,spurs], [frankfurt,napoli],[dortmund,chelsea],[inter,porto],[psg,bayern]] 
drawline() 

import random
random.shuffle(club_pair)

#1

for i in range(4):
    k1= 4*i+1; k2= 4*i+3
    draw(club_pair[i][0],k1);draw(club_pair[i][1],k2)
    draw(club_pair[7-i][0],n-k2);draw(club_pair[7-i][1],n-k1)

#2
quarter_final = [
                [win(club_pair[0]), win(club_pair[1])],
                [win(club_pair[2]), win(club_pair[3])],
                [win(club_pair[4]), win(club_pair[5])],
                [win(club_pair[6]), win(club_pair[7])],
                ]

for i in range(2):
    k1= 17+8*i+2; k2= 17+8*i+6
    draw(quarter_final[i][0],k1);draw(quarter_final[i][1],k2)
    draw(quarter_final[3-i][0],n-k2);draw(quarter_final[3-i][1],n-k1)

#3  
semi_final = [
                [win(quarter_final[0]), win(quarter_final[1])],
                [win(quarter_final[2]), win(quarter_final[3])]
                ]

k1= 17*2+4; k2= 17*2+12
draw(semi_final[0][0],k1);draw(semi_final[0][1],k2)
draw(semi_final[1][0],n-k2);draw(semi_final[1][1],n-k1)

#
final = [[win(semi_final[0]), win(semi_final[1])]]
    
    
k1= 17*3+8
draw(final[0][0],k1);draw(final[0][1],n-k1)

drawchamp(win(final[0]))
